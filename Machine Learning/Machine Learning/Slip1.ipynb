# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/iris.csv")

# %%
df.plot.scatter(x = 'sepal_length' , y='sepal_width' , title='scatter')
# Out:
# <AxesSubplot:title={'center':'scatter'}, xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x = 'petal_length' , y='petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>
